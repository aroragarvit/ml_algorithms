# %%
  # samples in a rows and features in columns of dataset  
import numpy as np
import pandas as pd 

def normalize(df):
    result = df.copy()
    for column in df.columns:
        max_value = df[column].max()
        min_value = df[column].min()
        if(max_value-min_value!=0):
            result[column] = (df[column] - min_value) / (max_value - min_value) 
        else:
            result[column]=df[column]
    return(result)    
        
data=pd.read_csv("houseprice.csv")
data.columns = (["housesize", "rooms", "price"])

normalised_data=normalize(data)


result = normalised_data.to_csv("result.csv",columns=['price'],index=False)

train = normalised_data.to_csv("train.csv",columns=['housesize',"rooms"],index=False)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True)

train=(pd.read_csv('train.csv'))                                 # norrmalised
train.insert(0,'ones',1)   # important function of pandas   

train=train.to_numpy()

result=(pd.read_csv('result.csv')).to_numpy()

epochs=[]
error=[]
class linear_regression:

     def __init__(self,train,result,epoches,alpha):
         self.train=train    #//  m*n+1
         self.result=result  #//  m*1
         samples,features=train.shape             # features will also contain 1-1-1-1 in them as first  column 
         self.samples=samples
         self.features=features
         self.weights=np.random.rand(features,1)  # n+1*1 # it will contain a single column and number of rows same as number of features
         self.epoches=epoches
         self.alpha=alpha
     def training(self):
         
         for i in range(self.epoches):
            epochs.append(i)
            prediction_matrix=np.dot(self.train,self.weights)  #// m*1                                                                                             # our predicted y result  according to our thetas  for features  of different samples
            mean_error=1/self.samples*(np.sum(np.square(np.subtract(prediction_matrix,self.result)),axis=0)) #// 1/2m*(sum of columns of square of elements of m*1-m*1 )      # column matrix with square error for different samples in each each row will do the sum of each of them to find overall error 
            print(" epochee${}-----------------Mean_square_error{}".format(i,mean_error))
            error.append(mean_error)
            weight_subtract_matrix =np.dot(np.transpose( np.subtract(prediction_matrix,self.result)),self.train)  #// (m*1 - m*1 )^T . m*n+1 = 1*n+1
            self.weights=np.subtract(self.weights,np.transpose(weight_subtract_matrix)*self.alpha/self.samples)  #// n+1*1 - n+1*1
        
a=linear_regression(train,result,epoches=250,alpha=0.01)

print(" random weights before training are")
print("-----------------------------------------------------------------------------------")
print(a.weights)
print("-----------------------------------------------------------------------------------")

a.training()

print("----------------------your final thetas after optimisation are-------------------------------------")
print(a.weights)

plt.title("Error With Each Epoches",loc = 'left')
plt.xlabel("epoches")
plt.ylabel("mean square error")
plt.plot(epochs,error)
plt.show()
# Out:
#  random weights before training are
# -----------------------------------------------------------------------------------
# [[0.57781778]
#  [0.90782869]
#  [0.77929753]]
# -----------------------------------------------------------------------------------
#  epochee$0-----------------Mean_square_error[0.97788747]
#  epochee$1-----------------Mean_square_error[0.95100992]
#  epochee$2-----------------Mean_square_error[0.92488638]
#  epochee$3-----------------Mean_square_error[0.89949571]
#  epochee$4-----------------Mean_square_error[0.87481734]
#  epochee$5-----------------Mean_square_error[0.85083129]
#  epochee$6-----------------Mean_square_error[0.82751814]
#  epochee$7-----------------Mean_square_error[0.804859]
#  epochee$8-----------------Mean_square_error[0.78283554]
#  epochee$9-----------------Mean_square_error[0.76142991]
#  epochee$10-----------------Mean_square_error[0.74062478]
#  epochee$11-----------------Mean_square_error[0.7204033]
#  epochee$12-----------------Mean_square_error[0.7007491]
#  epochee$13-----------------Mean_square_error[0.68164627]
#  epochee$14-----------------Mean_square_error[0.66307933]
#  epochee$15-----------------Mean_square_error[0.64503325]
#  epochee$16-----------------Mean_square_error[0.62749342]
#  epochee$17-----------------Mean_square_error[0.61044563]
#  epochee$18-----------------Mean_square_error[0.59387607]
#  epochee$19-----------------Mean_square_error[0.57777134]
#  epochee$20-----------------Mean_square_error[0.56211839]
#  epochee$21-----------------Mean_square_error[0.54690455]
#  epochee$22-----------------Mean_square_error[0.53211749]
#  epochee$23-----------------Mean_square_error[0.51774524]
#  epochee$24-----------------Mean_square_error[0.50377617]
#  epochee$25-----------------Mean_square_error[0.49019896]
#  epochee$26-----------------Mean_square_error[0.47700262]
#  epochee$27-----------------Mean_square_error[0.46417646]
#  epochee$28-----------------Mean_square_error[0.4517101]
#  epochee$29-----------------Mean_square_error[0.43959345]
#  epochee$30-----------------Mean_square_error[0.42781668]
#  epochee$31-----------------Mean_square_error[0.41637027]
#  epochee$32-----------------Mean_square_error[0.40524495]
#  epochee$33-----------------Mean_square_error[0.39443171]
#  epochee$34-----------------Mean_square_error[0.3839218]
#  epochee$35-----------------Mean_square_error[0.3737067]
#  epochee$36-----------------Mean_square_error[0.36377814]
#  epochee$37-----------------Mean_square_error[0.35412808]
#  epochee$38-----------------Mean_square_error[0.34474871]
#  epochee$39-----------------Mean_square_error[0.33563244]
#  epochee$40-----------------Mean_square_error[0.32677188]
#  epochee$41-----------------Mean_square_error[0.31815987]
#  epochee$42-----------------Mean_square_error[0.30978942]
#  epochee$43-----------------Mean_square_error[0.30165376]
#  epochee$44-----------------Mean_square_error[0.2937463]
#  epochee$45-----------------Mean_square_error[0.28606064]
#  epochee$46-----------------Mean_square_error[0.27859056]
#  epochee$47-----------------Mean_square_error[0.27133001]
#  epochee$48-----------------Mean_square_error[0.26427311]
#  epochee$49-----------------Mean_square_error[0.25741415]
#  epochee$50-----------------Mean_square_error[0.25074757]
#  epochee$51-----------------Mean_square_error[0.24426798]
#  epochee$52-----------------Mean_square_error[0.23797013]
#  epochee$53-----------------Mean_square_error[0.23184892]
#  epochee$54-----------------Mean_square_error[0.22589939]
#  epochee$55-----------------Mean_square_error[0.22011674]
#  epochee$56-----------------Mean_square_error[0.21449627]
#  epochee$57-----------------Mean_square_error[0.20903344]
#  epochee$58-----------------Mean_square_error[0.20372382]
#  epochee$59-----------------Mean_square_error[0.19856312]
#  epochee$60-----------------Mean_square_error[0.19354716]
#  epochee$61-----------------Mean_square_error[0.18867187]
#  epochee$62-----------------Mean_square_error[0.18393332]
#  epochee$63-----------------Mean_square_error[0.17932766]
#  epochee$64-----------------Mean_square_error[0.17485116]
#  epochee$65-----------------Mean_square_error[0.17050021]
#  epochee$66-----------------Mean_square_error[0.16627128]
#  epochee$67-----------------Mean_square_error[0.16216094]
#  epochee$68-----------------Mean_square_error[0.15816588]
#  epochee$69-----------------Mean_square_error[0.15428285]
#  epochee$70-----------------Mean_square_error[0.15050871]
#  epochee$71-----------------Mean_square_error[0.14684041]
#  epochee$72-----------------Mean_square_error[0.14327498]
#  epochee$73-----------------Mean_square_error[0.13980952]
#  epochee$74-----------------Mean_square_error[0.13644125]
#  epochee$75-----------------Mean_square_error[0.13316743]
#  epochee$76-----------------Mean_square_error[0.1299854]
#  epochee$77-----------------Mean_square_error[0.1268926]
#  epochee$78-----------------Mean_square_error[0.12388653]
#  epochee$79-----------------Mean_square_error[0.12096474]
#  epochee$80-----------------Mean_square_error[0.11812488]
#  epochee$81-----------------Mean_square_error[0.11536464]
#  epochee$82-----------------Mean_square_error[0.11268179]
#  epochee$83-----------------Mean_square_error[0.11007417]
#  epochee$84-----------------Mean_square_error[0.10753965]
#  epochee$85-----------------Mean_square_error[0.10507619]
#  epochee$86-----------------Mean_square_error[0.1026818]
#  epochee$87-----------------Mean_square_error[0.10035454]
#  epochee$88-----------------Mean_square_error[0.09809252]
#  epochee$89-----------------Mean_square_error[0.09589391]
#  epochee$90-----------------Mean_square_error[0.09375694]
#  epochee$91-----------------Mean_square_error[0.09167988]
#  epochee$92-----------------Mean_square_error[0.08966104]
#  epochee$93-----------------Mean_square_error[0.08769879]
#  epochee$94-----------------Mean_square_error[0.08579154]
#  epochee$95-----------------Mean_square_error[0.08393776]
#  epochee$96-----------------Mean_square_error[0.08213593]
#  epochee$97-----------------Mean_square_error[0.08038461]
#  epochee$98-----------------Mean_square_error[0.07868237]
#  epochee$99-----------------Mean_square_error[0.07702785]
#  epochee$100-----------------Mean_square_error[0.07541969]
#  epochee$101-----------------Mean_square_error[0.07385661]
#  epochee$102-----------------Mean_square_error[0.07233732]
#  epochee$103-----------------Mean_square_error[0.07086062]
#  epochee$104-----------------Mean_square_error[0.06942529]
#  epochee$105-----------------Mean_square_error[0.06803019]
#  epochee$106-----------------Mean_square_error[0.06667418]
#  epochee$107-----------------Mean_square_error[0.06535616]
#  epochee$108-----------------Mean_square_error[0.06407508]
#  epochee$109-----------------Mean_square_error[0.06282989]
#  epochee$110-----------------Mean_square_error[0.06161958]
#  epochee$111-----------------Mean_square_error[0.06044318]
#  epochee$112-----------------Mean_square_error[0.05929974]
#  epochee$113-----------------Mean_square_error[0.05818833]
#  epochee$114-----------------Mean_square_error[0.05710805]
#  epochee$115-----------------Mean_square_error[0.05605803]
#  epochee$116-----------------Mean_square_error[0.05503742]
#  epochee$117-----------------Mean_square_error[0.0540454]
#  epochee$118-----------------Mean_square_error[0.05308117]
#  epochee$119-----------------Mean_square_error[0.05214393]
#  epochee$120-----------------Mean_square_error[0.05123294]
#  epochee$121-----------------Mean_square_error[0.05034747]
#  epochee$122-----------------Mean_square_error[0.04948679]
#  epochee$123-----------------Mean_square_error[0.0486502]
#  epochee$124-----------------Mean_square_error[0.04783704]
#  epochee$125-----------------Mean_square_error[0.04704665]
#  epochee$126-----------------Mean_square_error[0.04627838]
#  epochee$127-----------------Mean_square_error[0.04553162]
#  epochee$128-----------------Mean_square_error[0.04480576]
#  epochee$129-----------------Mean_square_error[0.04410021]
#  epochee$130-----------------Mean_square_error[0.04341442]
#  epochee$131-----------------Mean_square_error[0.04274782]
#  epochee$132-----------------Mean_square_error[0.04209987]
#  epochee$133-----------------Mean_square_error[0.04147005]
#  epochee$134-----------------Mean_square_error[0.04085785]
#  epochee$135-----------------Mean_square_error[0.04026278]
#  epochee$136-----------------Mean_square_error[0.03968436]
#  epochee$137-----------------Mean_square_error[0.03912212]
#  epochee$138-----------------Mean_square_error[0.0385756]
#  epochee$139-----------------Mean_square_error[0.03804437]
#  epochee$140-----------------Mean_square_error[0.037528]
#  epochee$141-----------------Mean_square_error[0.03702606]
#  epochee$142-----------------Mean_square_error[0.03653816]
#  epochee$143-----------------Mean_square_error[0.0360639]
#  epochee$144-----------------Mean_square_error[0.0356029]
#  epochee$145-----------------Mean_square_error[0.03515478]
#  epochee$146-----------------Mean_square_error[0.03471919]
#  epochee$147-----------------Mean_square_error[0.03429577]
#  epochee$148-----------------Mean_square_error[0.03388418]
#  epochee$149-----------------Mean_square_error[0.0334841]
#  epochee$150-----------------Mean_square_error[0.03309519]
#  epochee$151-----------------Mean_square_error[0.03271714]
#  epochee$152-----------------Mean_square_error[0.03234965]
#  epochee$153-----------------Mean_square_error[0.03199242]
#  epochee$154-----------------Mean_square_error[0.03164517]
#  epochee$155-----------------Mean_square_error[0.03130762]
#  epochee$156-----------------Mean_square_error[0.03097948]
#  epochee$157-----------------Mean_square_error[0.03066051]
#  epochee$158-----------------Mean_square_error[0.03035043]
#  epochee$159-----------------Mean_square_error[0.03004901]
#  epochee$160-----------------Mean_square_error[0.029756]
#  epochee$161-----------------Mean_square_error[0.02947116]
#  epochee$162-----------------Mean_square_error[0.02919426]
#  epochee$163-----------------Mean_square_error[0.02892509]
#  epochee$164-----------------Mean_square_error[0.02866342]
#  epochee$165-----------------Mean_square_error[0.02840904]
#  epochee$166-----------------Mean_square_error[0.02816175]
#  epochee$167-----------------Mean_square_error[0.02792136]
#  epochee$168-----------------Mean_square_error[0.02768766]
#  epochee$169-----------------Mean_square_error[0.02746047]
#  epochee$170-----------------Mean_square_error[0.0272396]
#  epochee$171-----------------Mean_square_error[0.02702489]
#  epochee$172-----------------Mean_square_error[0.02681615]
#  epochee$173-----------------Mean_square_error[0.02661322]
#  epochee$174-----------------Mean_square_error[0.02641594]
#  epochee$175-----------------Mean_square_error[0.02622414]
#  epochee$176-----------------Mean_square_error[0.02603768]
#  epochee$177-----------------Mean_square_error[0.0258564]
#  epochee$178-----------------Mean_square_error[0.02568016]
#  epochee$179-----------------Mean_square_error[0.02550882]
#  epochee$180-----------------Mean_square_error[0.02534224]
#  epochee$181-----------------Mean_square_error[0.02518029]
#  epochee$182-----------------Mean_square_error[0.02502283]
#  epochee$183-----------------Mean_square_error[0.02486974]
#  epochee$184-----------------Mean_square_error[0.0247209]
#  epochee$185-----------------Mean_square_error[0.02457619]
#  epochee$186-----------------Mean_square_error[0.02443549]
#  epochee$187-----------------Mean_square_error[0.02429869]
#  epochee$188-----------------Mean_square_error[0.02416568]
#  epochee$189-----------------Mean_square_error[0.02403636]
#  epochee$190-----------------Mean_square_error[0.02391062]
#  epochee$191-----------------Mean_square_error[0.02378836]
#  epochee$192-----------------Mean_square_error[0.02366948]
#  epochee$193-----------------Mean_square_error[0.02355389]
#  epochee$194-----------------Mean_square_error[0.02344149]
#  epochee$195-----------------Mean_square_error[0.02333221]
#  epochee$196-----------------Mean_square_error[0.02322594]
#  epochee$197-----------------Mean_square_error[0.0231226]
#  epochee$198-----------------Mean_square_error[0.02302212]
#  epochee$199-----------------Mean_square_error[0.02292441]
#  epochee$200-----------------Mean_square_error[0.0228294]
#  epochee$201-----------------Mean_square_error[0.022737]
#  epochee$202-----------------Mean_square_error[0.02264715]
#  epochee$203-----------------Mean_square_error[0.02255978]
#  epochee$204-----------------Mean_square_error[0.0224748]
#  epochee$205-----------------Mean_square_error[0.02239217]
#  epochee$206-----------------Mean_square_error[0.02231181]
#  epochee$207-----------------Mean_square_error[0.02223365]
#  epochee$208-----------------Mean_square_error[0.02215764]
#  epochee$209-----------------Mean_square_error[0.02208372]
#  epochee$210-----------------Mean_square_error[0.02201182]
#  epochee$211-----------------Mean_square_error[0.0219419]
#  epochee$212-----------------Mean_square_error[0.02187389]
#  epochee$213-----------------Mean_square_error[0.02180774]
#  epochee$214-----------------Mean_square_error[0.0217434]
#  epochee$215-----------------Mean_square_error[0.02168082]
#  epochee$216-----------------Mean_square_error[0.02161994]
#  epochee$217-----------------Mean_square_error[0.02156073]
#  epochee$218-----------------Mean_square_error[0.02150314]
#  epochee$219-----------------Mean_square_error[0.02144711]
#  epochee$220-----------------Mean_square_error[0.02139261]
#  epochee$221-----------------Mean_square_error[0.02133959]
#  epochee$222-----------------Mean_square_error[0.02128801]
#  epochee$223-----------------Mean_square_error[0.02123783]
#  epochee$224-----------------Mean_square_error[0.02118902]
#  epochee$225-----------------Mean_square_error[0.02114152]
#  epochee$226-----------------Mean_square_error[0.02109532]
#  epochee$227-----------------Mean_square_error[0.02105036]
#  epochee$228-----------------Mean_square_error[0.02100662]
#  epochee$229-----------------Mean_square_error[0.02096406]
#  epochee$230-----------------Mean_square_error[0.02092264]
#  epochee$231-----------------Mean_square_error[0.02088234]
#  epochee$232-----------------Mean_square_error[0.02084313]
#  epochee$233-----------------Mean_square_error[0.02080497]
#  epochee$234-----------------Mean_square_error[0.02076783]
#  epochee$235-----------------Mean_square_error[0.02073169]
#  epochee$236-----------------Mean_square_error[0.02069652]
#  epochee$237-----------------Mean_square_error[0.02066229]
#  epochee$238-----------------Mean_square_error[0.02062897]
#  epochee$239-----------------Mean_square_error[0.02059654]
#  epochee$240-----------------Mean_square_error[0.02056498]
#  epochee$241-----------------Mean_square_error[0.02053425]
#  epochee$242-----------------Mean_square_error[0.02050434]
#  epochee$243-----------------Mean_square_error[0.02047522]
#  epochee$244-----------------Mean_square_error[0.02044688]
#  epochee$245-----------------Mean_square_error[0.02041928]
#  epochee$246-----------------Mean_square_error[0.02039241]
#  epochee$247-----------------Mean_square_error[0.02036625]
#  epochee$248-----------------Mean_square_error[0.02034078]
#  epochee$249-----------------Mean_square_error[0.02031597]
# ----------------------your final thetas after optimisation are-------------------------------------
# [[-0.08271159]
#  [ 0.69147802]
#  [ 0.38259947]]

# %%
from mpl_toolkits import mplot3d
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
house_data =pd.read_csv("houseprice.csv")
house_data.columns = (["housesize", "rooms", "price"])

x=house_data.housesize
y=house_data.rooms
z=house_data.price
fig = plt.figure(figsize = (5,5))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = "green")
plt.title("simple 3D scatter plot")
ax.set_xlabel('size', fontweight ='bold')
ax.set_ylabel('rooms', fontweight ='bold')
ax.set_zlabel('price', fontweight ='bold')
plt.show()

# %%
#def predict():
#def test_predict
# plot error theta graph if thetas less than equal  2
